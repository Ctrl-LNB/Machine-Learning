# %% [markdown]
# ## 1. Python Comment

# %%
## This is single line comment

'''This is multi line comment'''
# Out:
# 'This is multi line comment'

# %% [markdown]
# ## 2. Case Sensitive

# %%
age = 25
Age = 26

print(Age)
print(age)
# Out:
# 26
# 25

# %% [markdown]
# ## 3. Line Continuation

# %%
total = 1+1+1+1+1\
+1+1+1+1

print(total)
# Out:
# 9

# %% [markdown]
# ## 4. Type Inference

# %%
## Dynamic typed code

var = 25
print(type(var))

var = 25.01
print(type(var))

var = "Barsha"
print(type(var))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ## 5. Indentation

# %%
## block under any statement -- usually 4 spaces

age = 2

if(age > 20):
    print("Senior Cityzen")
    print("Inside conditional block")
    
print("Outside condition")
# Out:
# Outside condition
