# %%
range(5)
# Out:
# range(0, 5)

# %%
## for loop

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
## range(start, end, step)
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10,1,-1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
for i in range(10,1,-2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
## strings
str = "Suhana Mou"

for i in str:
    print(i)
# Out:
# S
# u
# h
# a
# n
# a
#
# M
# o
# u

# %%
## while loop
## The whie loop condition to execute as long as the condition is true.

count = 0

while count < 5:
    print(count)
    count = count+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
## Loop Control Statements

## break
## The break statement exits the loop prematurely

## break statement

for i in range(10):
    if i==6:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
## Continue
## The continue statement skips the cuurent iteration and continues with the next.

for i in range(10):
    if i%2==0:
       continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
## Pass
## THe pass statement is a null operation; it does nothing.

for i in range(5):
    if i==3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
## Nested loops
## A loop inside a loop

for i in range(3):
    for j in range(2):
        print(f"i:{i} and j:{j}")
# Out:
# i:0 and j:0
# i:0 and j:1
# i:1 and j:0
# i:1 and j:1
# i:2 and j:0
# i:2 and j:1

# %%
## Examples: Calculate the sum of first N natural umbers using a while nad for loop.

## while loop

n = 10
sum = 0
count = 1

while count <= n:
    sum = sum+count
    count = count+1
print("sum of first 10 natural number:", sum)
# Out:
# sum of first 10 natural number: 55

# %%
n = 10
sum = 0
for i in range(11):
    sum = sum+i
print (sum)
# Out:
# 55

# %%
## Example: Prime numbers between 1 and 10

for num in range(1,10):
    if num>1:
        for i in range(2,num):
            if num%i==0:
                break
        else:
            print(num)
# Out:
# 2
# 3
# 5
# 7
