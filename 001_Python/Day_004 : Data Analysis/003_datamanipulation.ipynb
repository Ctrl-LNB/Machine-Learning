# %% [markdown]
# #### Data Manipulation and Analysis with Pandas
#
# ###### Data Manipulation nd analysis are key tasks in any data science or data analysis project. Pandas provides a wide range of functions for data manipulation and anlysis., making it easier to clran, trasform, and extract insights from data. In this lesson, we will cover variour data manipulation and analysis techniques using Pandas.

# %%
import pandas as pd

# %%
df= pd.read_csv('data.csv')
## Fecth the first 5 rows
df.head(5)
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.tail(5)
# Out:
#           Date Category  Value   Product  Sales Region
# 25  2023-01-26        B   24.0  Product1  455.0  South
# 26  2023-01-27        A   41.0  Product2  845.0   West
# 27  2023-01-28        C   30.0  Product3  605.0  North
# 28  2023-01-29        B   17.0  Product1  295.0   East
# 29  2023-01-30        A   46.0  Product2  995.0  South

# %%
df.describe()
# Out:
#            Value        Sales
# count  30.000000    30.000000
# mean   30.733333   620.600000
# std    11.764744   283.068726
# min     8.000000   110.000000
# 25%    22.500000   406.000000
# 50%    30.500000   612.500000
# 75%    39.750000   831.250000
# max    51.000000  1250.000000

# %%
df.dtypes
# Out:
# Date            str
# Category        str
# Value       float64
# Product         str
# Sales       float64
# Region          str
# dtype: object

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
## Handling Missing Values
df.isnull().any()
# Out:
# Date        False
# Category    False
# Value       False
# Product     False
# Sales       False
# Region      False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       0
# Product     0
# Sales       0
# Region      0
# dtype: int64

# %%
df.filled=df.fillna(0)

# %%
df.columns
# Out:
# Index(['Date', 'Category', 'Value', 'Product', 'Sales', 'Region',
#        'Sales_fillna'],
#       dtype='str')

# %%
## Filling missing values with the mean of the column
df['Sales_fillna']=df['Sales'].fillna(df['Sales'].mean())
df
# Out:
#           Date Category  Value   Product   Sales Region  Sales_fillna
# 0   2023-01-01        A   28.0  Product1   754.0   East         754.0
# 1   2023-01-02        B   39.0  Product3   110.0  North         110.0
# 2   2023-01-03        C   32.0  Product2   398.0   East         398.0
# 3   2023-01-04        B    8.0  Product1   522.0   East         522.0
# 4   2023-01-05        B   26.0  Product3   869.0  North         869.0
# 5   2023-01-06        A   45.0  Product2   650.0  South         650.0
# 6   2023-01-07        C   19.0  Product1   320.0   West         320.0
# 7   2023-01-08        B   51.0  Product3   980.0  North         980.0
# 8   2023-01-09        A   14.0  Product2   270.0   East         270.0
# 9   2023-01-10        C   37.0  Product1   745.0  South         745.0
# 10  2023-01-11        B   22.0  Product2   430.0   West         430.0
# 11  2023-01-12        A   48.0  Product3  1120.0  North        1120.0
# ...

# %%
df.dtypes
# Out:
# Date                str
# Category            str
# Value           float64
# Product             str
# Sales           float64
# Region              str
# Sales_fillna    float64
# dtype: object

# %%
## Renaming Columns
df.rename(columns={'Date':'Sale Date'})
df.head()
# Out:
#          Date Category  Value   Product  Sales Region  Sales_fillna
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0

# %%
## Change datatypes
df['Value_new']=df['Value'].fillna (df['Value'].mean()).astype(int)
df.head()
# Out:
#          Date Category  Value   Product  Sales Region  Sales_fillna  Value_new
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0         28
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0         39
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0         32
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0          8
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0         26
