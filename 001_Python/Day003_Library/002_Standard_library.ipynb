# %% [markdown]
# ### Standard Library Overview
#
# ##### Python's Standard Library is a vast collection of modules and packages that come bundled with python,providing a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and packages in the python Standard Library.

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## Random

import random
print(random.randint(1,10))
print(random.choice(['apple','banana','charry']))
# Out:
# 3
# charry

# %%
## File and Directory Access

import os 
print(os.getcwd())
# Out:
# e:\Languages\Python Practice\Day003_Library

# %%
os.mkdir('test_dir')

# %%
## High level opretaions on files and collection of files

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data serialization

import json
data={'name':'Barsha','age':24}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Barsha", "age": 24}
# <class 'str'>
# {'name': 'Barsha', 'age': 24}
# <class 'dict'>

# %%
## Csv

import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Barsha',24])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Barsha', '24']

# %%
## Datetime
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)

print(yesterday)
# Out:
# 2026-07-15 23:44:26.503838
# 2026-07-14 23:44:26.503838

# %%
## Time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1784137562.2756124
# 1784137564.277401

# %%
## Regular expresiton

import re

pattern=r'\d+'
text='There are 123 apples 456'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
